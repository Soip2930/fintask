# %% [markdown]
# # Шаг 1. Импортируйте необходимые библиотеки

# %%
#ипортирование библиотек
import pandas as pd
import numpy as np
import matplotlib as mpl
import seaborn as sns

# %% [markdown]
# # Шаг 2. Импортируйте набор данных с этого [адреса](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Online_Retail/Online_Retail.csv).

# %%
# импортированеи данных
pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Online_Retail/Online_Retail.csv',
            encoding = 'latin1')
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %% [markdown]
# # Шаг 3. Сохраните его в переменной с именем online_rt.
# В случае появления utf-8 decode error, используйте параметр encoding = 'latin1' в pd.read_csv()

# %%
#вводим переменную
online_rt = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Online_Retail/Online_Retail.csv', encoding = 'latin1')
online_rt.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#     InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/10 8:26       2.55     17850.0  United Kingdom
# 1  12/1/10 8:26       3.39     17850.0  United Kingdom
# 2  12/1/10 8:26       2.75     17850.0  United Kingdom
# 3  12/1/10 8:26       3.39     17850.0  United Kingdom
# 4  12/1/10 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# # Шаг 4. Постройте столбчатый график с 10 странами, в которых наибольшее количество 'Quantity' за исключением UK

# %%
#Строим график
online_rt_x = online_rt.sort_values(by="Quantity", ascending=False)
online_rt_x = online_rt_x[~online_rt_1['Country'].isin(['United Kingdom'])]
online_rt_x.head(10)
online_rt_x.groupby("Country")["Quantity"].max().sort_values()
# Out:
# Country
# Saudi Arabia              12
# RSA                       12
# Brazil                    24
# Lebanon                   24
# European Community        24
# Unspecified               48
# Malta                     48
# Lithuania                 48
# Greece                    48
# USA                       72
# Poland                    72
# Czech Republic            72
# United Arab Emirates      72
# Bahrain                   96
# Israel                   100
# Portugal                 120
# Hong Kong                144
# Finland                  144
# Italy                    200
# Norway                   240
# Iceland                  240
# Denmark                  256
# Belgium                  272
# Cyprus                   288
# Switzerland              288
# Austria                  288
# Singapore                288
# Spain                    360
# Channel Islands          407
# Canada                   504
# Germany                  600
# ...

# %% [markdown]
# # Шаг 5.  Исключите строки с отрицательным Quantity¶

# %%
online_rt_new = online_rt.set_index('Quantity')
online_rt_new.query("~(Quantity < 0)")
# Out:
#          InvoiceNo StockCode                          Description  \
# Quantity
# 6           536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER
# 6           536365     71053                  WHITE METAL LANTERN
# 8           536365    84406B       CREAM CUPID HEARTS COAT HANGER
# 6           536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE
# 6           536365    84029E       RED WOOLLY HOTTIE WHITE HEART.
# ...            ...       ...                                  ...
# 12          581587     22613          PACK OF 20 SPACEBOY NAPKINS
# 6           581587     22899         CHILDREN'S APRON DOLLY GIRL
# 4           581587     23254        CHILDRENS CUTLERY DOLLY GIRL
# 4           581587     23255      CHILDRENS CUTLERY CIRCUS PARADE
# 3           581587     22138        BAKING SET 9 PIECE RETROSPOT
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# Quantity
# 6          12/1/10 8:26       2.55     17850.0  United Kingdom
# ...

# %% [markdown]
# # Шаг 6. Постройте точечный график с соотношением Quantity к  UnitPrice для стран 'Netherlands', 'EIRE', 'Germany'

# %%
online_rt.Country.unique()
online_rt_newest = online_rt[~online_rt['Country'].isin(['United Kingdom', 'France', 'Australia', 'Norway', 'Switzerland', 'Spain', 'Poland', 'Portugal',
       'Italy', 'Belgium', 'Lithuania', 'Japan', 'Iceland',
       'Channel Islands', 'Denmark', 'Cyprus', 'Sweden', 'Austria',
       'Israel', 'Finland', 'Bahrain', 'Greece', 'Hong Kong', 'Singapore',
       'Lebanon', 'United Arab Emirates', 'Saudi Arabia',
       'Czech Republic', 'Canada', 'Unspecified', 'Brazil', 'USA',
       'European Community', 'Malta', 'RSA'])]
online_rt_newest

sns.scatterplot(data=online_rt_newest, x="Quantity", y="UnitPrice" , hue = 'Country');

# %% [markdown]
# # Шаг 7. Нарисуйте график, который отображает revenue (y) по отношению к UnitPrice (x)

# %%
x = online_rt[online_rt['Quantity'] > 0]
online_rt_1 = t.groupby('UnitPrice')['Quantity'].sum()
online_rt_1 = pd.DataFrame(online_rt_1)
online_rt_1['UnitPrice'] = online_rt_1.index
online_rt_1['revenue']= online_rt_1['UnitPrice']*online_rt_1['Quantity']
online_rt_2= online_rt_1[online_rt_1['UnitPrice'] !=0]
sns.jointplot(data=online_rt_2, x="UnitPrice", y="revenue", kind='reg')
